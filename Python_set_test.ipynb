# %%
pos_words_set = set()
print(pos_words_set)
# Out:
# set()

# %%
# !ls
# Out:
# CovidComparison-old.ipynb
# CovidComparison.ipynb
# Python_set_test.ipynb
# README.md
# SparkTest.ipynb
# bigdata_prototype.ddb
# sentiment_txts
# small_data.sh
# small_reddit.csv
# small_twitter.csv
# spark-3.5.3-bin-hadoop3

# %%
with open('sentiment_txts/positive_words_en.txt','r') as file:
    for line in file:
        pos_words_set.add(line.strip())
print(pos_words_set)
# Out:
# {'masterfully', 'radiant', 'supporting', 'enticing', 'excelled', 'usable', 'solicitously', 'compassionate', 'advocates', 'enthral', 'merriment', 'succeeds', 'righten', 'smoother', 'awed', 'beckon', 'wise', 'fashionable', 'elegant', 'chaste', 'tidy', 'unequivocally', 'pepped', 'logical', 'nicest', 'resplendent', 'rapt', 'intrigue', 'speedy', 'admiringly', 'exaltation', 'feisty', 'boost', 'handsome', 'brave', 'straighten', 'shimmering', 'meritorious', 'remarkable', 'breathtaking', 'exceled', 'fanfare', 'trouble-free', 'intuitive', 'elate', 'reassure', 'supremacy', 'appreciate', 'magnificence', 'respite', 'efficacious', 'regally', 'envious', 'richer', 'harmoniously', 'convience', 'bonny', 'standout', 'affordable', 'sustainability', 'hale', 'dotingly', 'idolize', 'distinguished', 'fabulous', 'magic', 'amity', 'sprightly', 'virtuously', 'intelligible', 'gentlest', 'luckier', 'affirmation', 'master', 'calm', 'picturesque', 'lush', 'harmonious', 'reasoned', 'transparent', 'guidance', 'award
# ...
